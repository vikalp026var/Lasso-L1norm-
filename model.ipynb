# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import accuracy_score,r2_score,classification_report
import pickle

# %%
df=pd.read_csv('Salary_Data2.csv')

# %%
df
# Out:
#     Years  Experience    Salary
# 0       0         1.1   39343.0
# 1       1         1.3   46205.0
# 2       2         1.5   37731.0
# 3       3         2.0   43525.0
# 4       4         2.2   39891.0
# 5       5         2.9   56642.0
# 6       6         3.0   60150.0
# 7       7         3.2   54445.0
# 8       8         3.2   64445.0
# 9       9         3.7   57189.0
# 10     10         3.9   63218.0
# 11     11         4.0   55794.0
# 12     12         4.0   56957.0
# 13     13         4.1   57081.0
# 14     14         4.5   61111.0
# 15     15         4.9   67938.0
# 16     16         5.1   66029.0
# 17     17         5.3   83088.0
# 18     18         5.9   81363.0
# 19     19         6.0   93940.0
# 20     20         6.8   91738.0
# 21     21         7.1   98273.0
# 22     22         7.9  101302.0
# 23     23         8.2  113812.0
# 24     24         8.7  109431.0
# 25     25         9.0  105582.0
# 26     26         9.5  116969.0
# 27     27         9.6  112635.0
# 28     28        10.3  122391.0
# 29     29        10.5  121872.0
# 30     30         NaN       NaN

# %%
#EDA

# %%
df.isnull().sum()
# Out:
# Years         0
# Experience    1
# Salary        1
# dtype: int64

# %%
df.dtypes
# Out:
# Years           int64
# Experience    float64
# Salary        float64
# dtype: object

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Years  Experience    Salary
# 0       0         1.1   39343.0
# 1       1         1.3   46205.0
# 2       2         1.5   37731.0
# 3       3         2.0   43525.0
# 4       4         2.2   39891.0
# 5       5         2.9   56642.0
# 6       6         3.0   60150.0
# 7       7         3.2   54445.0
# 8       8         3.2   64445.0
# 9       9         3.7   57189.0
# 10     10         3.9   63218.0
# 11     11         4.0   55794.0
# 12     12         4.0   56957.0
# 13     13         4.1   57081.0
# 14     14         4.5   61111.0
# 15     15         4.9   67938.0
# 16     16         5.1   66029.0
# 17     17         5.3   83088.0
# 18     18         5.9   81363.0
# 19     19         6.0   93940.0
# 20     20         6.8   91738.0
# 21     21         7.1   98273.0
# 22     22         7.9  101302.0
# 23     23         8.2  113812.0
# 24     24         8.7  109431.0
# 25     25         9.0  105582.0
# 26     26         9.5  116969.0
# 27     27         9.6  112635.0
# 28     28        10.3  122391.0
# 29     29        10.5  121872.0

# %%
df['Years']=df['Years'].astype('float')

# %%
df
# Out:
#     Years  Experience    Salary
# 0     0.0         1.1   39343.0
# 1     1.0         1.3   46205.0
# 2     2.0         1.5   37731.0
# 3     3.0         2.0   43525.0
# 4     4.0         2.2   39891.0
# 5     5.0         2.9   56642.0
# 6     6.0         3.0   60150.0
# 7     7.0         3.2   54445.0
# 8     8.0         3.2   64445.0
# 9     9.0         3.7   57189.0
# 10   10.0         3.9   63218.0
# 11   11.0         4.0   55794.0
# 12   12.0         4.0   56957.0
# 13   13.0         4.1   57081.0
# 14   14.0         4.5   61111.0
# 15   15.0         4.9   67938.0
# 16   16.0         5.1   66029.0
# 17   17.0         5.3   83088.0
# 18   18.0         5.9   81363.0
# 19   19.0         6.0   93940.0
# 20   20.0         6.8   91738.0
# 21   21.0         7.1   98273.0
# 22   22.0         7.9  101302.0
# 23   23.0         8.2  113812.0
# 24   24.0         8.7  109431.0
# 25   25.0         9.0  105582.0
# 26   26.0         9.5  116969.0
# 27   27.0         9.6  112635.0
# 28   28.0        10.3  122391.0
# 29   29.0        10.5  121872.0

# %%
df.dtypes
# Out:
# Years         float64
# Experience    float64
# Salary        float64
# dtype: object

# %%
X=df.iloc[:,:-1]

# %%
X
# Out:
#     Years  Experience
# 0     0.0         1.1
# 1     1.0         1.3
# 2     2.0         1.5
# 3     3.0         2.0
# 4     4.0         2.2
# 5     5.0         2.9
# 6     6.0         3.0
# 7     7.0         3.2
# 8     8.0         3.2
# 9     9.0         3.7
# 10   10.0         3.9
# 11   11.0         4.0
# 12   12.0         4.0
# 13   13.0         4.1
# 14   14.0         4.5
# 15   15.0         4.9
# 16   16.0         5.1
# 17   17.0         5.3
# 18   18.0         5.9
# 19   19.0         6.0
# 20   20.0         6.8
# 21   21.0         7.1
# 22   22.0         7.9
# 23   23.0         8.2
# 24   24.0         8.7
# 25   25.0         9.0
# 26   26.0         9.5
# 27   27.0         9.6
# 28   28.0        10.3
# 29   29.0        10.5

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train.shape
# Out:
# (20, 2)

# %%
X_test
# Out:
#     Years  Experience
# 27   27.0         9.6
# 15   15.0         4.9
# 23   23.0         8.2
# 17   17.0         5.3
# 8     8.0         3.2
# 9     9.0         3.7
# 28   28.0        10.3
# 24   24.0         8.7
# 12   12.0         4.0
# 0     0.0         1.1

# %%
y_train.shape
# Out:
# (20,)

# %%
regression=LinearRegression()
ridge=Ridge()
lasso=Lasso()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([116409.1781502 ,  70396.92194323, 102970.56854528,  73698.37031037,
#         55423.99622293,  60492.57684182, 123756.32972598, 108039.14916417,
#         62026.8929572 ,  36521.77536217])

# %%
ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
y_pred1=ridge.predict(X_test)

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso()

# %%
y_pred2=lasso.predict(X_test)

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.9549606670205707

# %%
print(r2_score(y_test,y_pred1))
# Out:
# 0.9549610962362659

# %%
print(r2_score(y_test,y_pred2))
# Out:
# 0.9549652643040706

# %%
max(0.9549610962362659,0.9549610962362659,0.9549652643040706)
# Out:
# 0.9549652643040706

# %%
pickle.dump(lasso,open('regression.pkl','wb'))

# %%
u=pickle.load(open('regression.pkl','rb'))

# %%
u.predict(X_test)
# Out:
# array([116406.57134856,  70400.6164452 , 102968.95752629,  73703.55529441,
#         55424.46241106,  60491.79989759, 123751.15420971, 108036.29501282,
#         62030.34010947,  36519.5935777 ])
